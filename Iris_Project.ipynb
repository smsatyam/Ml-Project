# %% [markdown]
# # Iris Project for data Visulization

# %%
#all library we can copy in document and use it in every project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from numpy.random import randn
from pandas.plotting import scatter_matrix

#ignore the warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.864842  0.134525 -0.972735  1.026418
# 1  1.026272 -0.059967  0.588130 -1.893975
# 2 -1.101502 -0.425298 -0.998130 -0.796601
# 3  0.277412  0.397828 -0.230886 -1.023658
# 4 -0.185876 -0.299190 -1.053697  0.319367
# 5 -0.432519  1.107628  1.130882 -0.806870
# 6  0.478346  0.705118  0.716383  1.651881
# 7  0.067502  1.451046 -0.390176  0.334783
# 8 -0.884607  2.130981  1.667036  0.322602
# 9  1.195108  0.420962  0.802477 -1.757346

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
iris=sns.load_dataset('iris')

# %%
iris.sample(n=7)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 114           5.8          2.8           5.1          2.4  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 3             4.6          3.1           1.5          0.2     setosa
# 131           7.9          3.8           6.4          2.0  virginica
# 130           7.4          2.8           6.1          1.9  virginica

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#balanced data set only else you can check the results

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
new_species=pd.Categorical(iris['species'])
new_species=new_species.rename_categories([0,1,2])
iris['species']=new_species

# %%
iris['species']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: category
# Categories (3, int64): [0, 1, 2]

# %%
#Data Visulization techniques
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
iris.sepal_length.plot(kind='hist',bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df=iris.drop(columns='species')

# %%
df.hist(color='b', figsize=(10,5))
plt.show()  #ploting in the size , alpha = thickness of the colors

# %%
df.plot(kind='box',figsize=(10,5),color='r',vert=True)
# Out:
# <AxesSubplot:>

# %%
scatter_matrix(df,figsize=(15,15),diagonal='kde',color='b')
plt.show()

# %%
sns.pairplot(iris,hue='species')

# %%
d=df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize=(10,10),autopct='%.1f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
df.plot(kind='area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #A scatter plot (also called a scatterplot, scatter graph, scatter chart, scattergram, or scatter diagram) is a type of plot or mathematical diagram using Cartesian coordinates to display values for typically
# #two variables for a set of data.

# %%
df.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
tips=sns.load_dataset('tips')
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(x= 'total_bill', y='tip', data=tips, hue= 'smoker',style = 'time')
plt.show()

# %%
#2. Categorical Data Ploting
sns.catplot(x='day',y='total_bill', data=tips)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.distplot(iris)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.regplot(x='total_bill',y='tip',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
#probability lies between 0-1

import scipy.stats as st

mu=494
std=100
x=700
1-st.norm.cdf(x,loc=mu,scale=std)
1-st.norm.cdf(x,loc=mu,scale=std)
# Out:
# 0.019699270409376912
